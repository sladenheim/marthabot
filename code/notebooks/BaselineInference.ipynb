# %% [markdown]
# # Baseline Inference

# %% [markdown]
# **Task**: Establish baseline answers to Martha Graham interview questions using two approaches:
# - Zero shot prompting (minimal prompting)
# - Dedicated zero shot prompting

# %%
# imports
import
