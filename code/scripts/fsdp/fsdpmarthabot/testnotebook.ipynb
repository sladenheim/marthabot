# %%
# Test clm_dataset.py file 
from clm_dataset import marthabot_clm_dataset
from torch.utils.data import DataLoader

dataset_path = "/projectnb/scottml/seansal2/data/datasets/blood_memory_clm_train"

dataset = marthabot_clm_dataset(dataset_path)

print(f"Loaded dataset with {len(dataset)} examples")

sample = dataset[0]
print(f"Sample keys: {sample.keys()}")
print(f"input_ids shape: {sample['input_ids'].shape}")
print(f"attention_mask shape: {sample['attention_mask'].shape}")
print(f"labels shape: {sample['labels'].shape}")
# Out:
# Loaded dataset with 82 examples
# Sample keys: dict_keys(['input_ids', 'attention_mask', 'labels'])
# input_ids shape: torch.Size([1024])
# attention_mask shape: torch.Size([1024])
# labels shape: torch.Size([1024])
